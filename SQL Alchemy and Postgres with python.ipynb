# %%
from sqlalchemy import create_engine
import pandas as pd
import sqlalchemy
import pyodbc
import psycopg2
#DBeaver

# default
#engine = create_engine('postgresql://scott:tiger@localhost/mydatabase')

#engine = create_engine('postgresql://postgres:5432@localhost/dvd')
#engine

# %%
connection_uri = 'postgresql://postgres:12345@localhost:5432/dvd'
connection_uri
# Out:
# 'postgresql://postgres:12345@localhost:5432/dvd'

# %%
db_engine_dwh = sqlalchemy.create_engine(connection_uri)
db_engine_dwh
# Out:
# Engine(postgresql://postgres:***@localhost:5432/dvd)

# %%
connection = db_engine_dwh.connect()
connection

# %%
df = pd.read_sql('SELECT * FROM address', connection)
df
# pd.read_sql_query
# Out:
#      address_id                                address address2  \
# 0             1                      47 MySakila Drive     None
# 1             2                     28 MySQL Boulevard     None
# 2             3                      23 Workhaven Lane     None
# 3             4                   1411 Lillydale Drive     None
# 4             5                         1913 Hanoi Way
# 5             6                       1121 Loja Avenue
# 6             7                      692 Joliet Street
# 7             8                       1566 Inegl Manor
# 8             9                        53 Idfu Parkway
# 9            10        1795 Santiago de Compostela Way
# 10           11     900 Santiago de Compostela Parkway
# 11           12                         478 Joliet Way
# 12           13                      613 Korolev Drive
# 13           14                         1531 Sal Drive
# 14           15                    1542 Tarlac Parkway
# ...

# %%
df_1 = pd.read_sql('SELECT * FROM address WHERE address_id=1', connection)
df_1
# Out:
#    address_id            address address2 district  city_id postal_code phone  \
# 0           1  47 MySakila Drive     None  Alberta      300
#
#           last_update
# 0 2006-02-15 09:45:30

# %%
df_2 = pd.read_sql('SELECT * FROM address WHERE address_id=2', connection)
df_2
# Out:
#    address_id             address address2 district  city_id postal_code  \
# 0           2  28 MySQL Boulevard     None      QLD      576
#
#   phone         last_update
# 0       2006-02-15 09:45:30

# %% [raw]
# ###############################################################################
# Average rating per course

# %%
df_a = df.groupby('district').city_id.mean()
type(df_a)

print(df_a)
# Out:
# district
#                        399.000000
# Abu Dhabi                7.500000
# Aceh                   301.000000
# Adana                  267.000000
# Addis Abeba              6.000000
# Aden                     7.000000
# Adygea                 320.000000
# Ahal                    35.000000
# Alberta                300.000000
# Alto Paran             122.000000
# Andhra Pradesh         217.000000
# Anhalt Sachsen         198.000000
# Antofagasta             27.000000
# Anzotegui               55.000000
# Apulia                  93.000000
# Arecibo                 32.000000
# Asir                     2.000000
# Assam                  354.000000
# Asturia                181.000000
# Asuncin                 37.000000
# Attika                  38.000000
# Baden-Wrttemberg       325.000000
# Baijeri                160.000000
# Baja California        335.000000
# Baja California Sur    288.000000
# Baki                    48.000000
# Balikesir               50.000000
# ...

# %% [raw]
# # Complete the transformation function
# def transform_avg_rating(rating_data):
#
#   # Group by course_id and extract average rating per course
#   avg_rating = rating_data.groupby('course_id').rating.mean()
#
#   # Return sorted average ratings per course
#   sort_rating = avg_rating.sort_values(ascending=False).reset_index()
#
#   return sort_rating
#
# # Extract the rating data into a DataFrame
# rating_data = extract_rating_data(db_engines) = df
#
# # Use transform_avg_rating on the extracted data and print results
# avg_rating_data = transform_avg_rating(rating_data)
#
#
# print(avg_rating_data)

# %% [raw]
# Filter out corrupt data

# %%
df = pd.read_sql('SELECT * FROM address', connection)
df
# Out:
#      address_id                                address address2  \
# 0             1                      47 MySakila Drive     None
# 1             2                     28 MySQL Boulevard     None
# 2             3                      23 Workhaven Lane     None
# 3             4                   1411 Lillydale Drive     None
# 4             5                         1913 Hanoi Way
# 5             6                       1121 Loja Avenue
# 6             7                      692 Joliet Street
# 7             8                       1566 Inegl Manor
# 8             9                        53 Idfu Parkway
# 9            10        1795 Santiago de Compostela Way
# 10           11     900 Santiago de Compostela Parkway
# 11           12                         478 Joliet Way
# 12           13                      613 Korolev Drive
# 13           14                         1531 Sal Drive
# 14           15                    1542 Tarlac Parkway
# ...

# %%
df.isnull().sum()
# Out:
# address_id     0
# address        0
# address2       4
# district       0
# city_id        0
# postal_code    0
# phone          0
# last_update    0
# dtype: int64

# %%
def transform_fill_programming_language(course_data):
    imputed = course_data.fillna({"programming_language": "r"})
    return imputed

# %%
x = df.fillna(0)

# %%
x.isnull().sum()
# Out:
# address_id     0
# address        0
# address2       0
# district       0
# city_id        0
# postal_code    0
# phone          0
# last_update    0
# dtype: int64

# %%
Filter out corrupt data

# %%
df = pd.read_sql('SELECT * FROM address', connection)
df = course_data

# %%
# The transformation should fill in the missing values
def transform_fill_programming_language(course_data):
    imputed = course_data.fillna(0)
    return imputed

transformed = transform_fill_programming_language(course_data)

# Print out the number of missing values per column of transformed
print(transformed.isnull().sum())
# Out:
# address_id     0
# address        0
# address2       0
# district       0
# city_id        0
# postal_code    0
# phone          0
# last_update    0
# dtype: int64

# %%
# Complete the transformation function
def transform_recommendations(avg_course_ratings, courses_to_recommend):
    
    # Merge both DataFrames
    merged = courses_to_recommend.merge(avg_course_ratings)
    
    # Sort values by rating and group by user_id
    grouped = merged.sort_values("rating", ascending = False).groupby('user_id')
    
    # Produce the top 3 values and sort by user_id
    recommendations = grouped.head(3).sort_values("user_id").reset_index()
    
    final_recommendations = recommendations[["user_id", "course_id","rating"]]
    # Return final recommendations
    return final_recommendations

# %%
# Use the function with the predefined DataFrame objects
recommendations = transform_recommendations(avg_course_ratings, courses_to_recommend)

# %%
# Complete the SELECT statement
data = pd.read_sql("""
SELECT * FROM "Customer"
INNER JOIN "Order"
ON "Order"."customer_id"="Customer"."id"
""", db_engine)

# Show the id column of data
print(data.id)

# %%
# Function to apply a function over multiple cores
@print_timing
def parallel_apply(apply_func, groups, nb_cores):
    with Pool(nb_cores) as p:
        results = p.map(apply_func, groups)
    return pd.concat(results)

# Parallel apply using 1 core
parallel_apply(take_mean_age, athlete_events.groupby('Year'), ____)

# Parallel apply using 2 cores
parallel_apply(take_mean_age, athlete_events.groupby('Year'), ____)

# Parallel apply using 4 cores
parallel_apply(take_mean_age, athlete_events.groupby('Year'), ____)

# %%
import dask.dataframe as dd

# Set the number of partitions
athlete_events_dask = dd.from_pandas(athlete_events, npartitions = 4)
